# %% [markdown]
# ## Import libraries & set random seed

# %%
import numpy as np
import pandas as pd
import os
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from PIL import Image
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import matplotlib.pyplot as plt
import warnings
import copy
warnings.filterwarnings('ignore')

manualSeed = 999
np.random.seed(manualSeed)
torch.manual_seed(manualSeed)
print("Random Seed:", manualSeed)

image_dir = '/kaggle/input/isic-2024-challenge/train-image/image'
meta_dir = "/kaggle/input/isic-2024-challenge/"
save_dir = '/kaggle/working/processed_images'
os.makedirs(save_dir, exist_ok=True)

image_files = os.listdir(image_dir)[:10]

for i, file_name in enumerate(image_files, 1):
    image_path = os.path.join(image_dir, file_name)
    with Image.open(image_path) as img:
        print(f"Image {i}: {file_name} - Size: {img.size}")
# Out:
# Random Seed: 999
# Image 1: ISIC_9730802.jpg - Size: (139, 139)
# Image 2: ISIC_2834883.jpg - Size: (125, 125)
# Image 3: ISIC_5115027.jpg - Size: (123, 123)
# Image 4: ISIC_3264822.jpg - Size: (115, 115)
# Image 5: ISIC_1950204.jpg - Size: (147, 147)
# Image 6: ISIC_8411738.jpg - Size: (145, 145)
# Image 7: ISIC_3744117.jpg - Size: (133, 133)
# Image 8: ISIC_0989720.jpg - Size: (131, 131)
# Image 9: ISIC_3926794.jpg - Size: (139, 139)
# Image 10: ISIC_2892810.jpg - Size: (107, 107)

# %% [markdown]
# ## Load & Filter Data

# %%
df = pd.read_csv(meta_dir + "train-metadata.csv")

malignant_df = df[df["target"] == 1]
benign_df = df[df["target"] == 0].sample(n=10000, random_state=42)
df_filtered = pd.concat([malignant_df, benign_df]).reset_index(drop=True)

# %% [markdown]
# ## Apply Hair Removal preprocessing technique function (DullRazor)

# %%
def remove_hairs_dullrazor(img):
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (9, 9))
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)
    _, hair_mask = cv2.threshold(blackhat, 10, 255, cv2.THRESH_BINARY)
    hair_mask = cv2.dilate(hair_mask, np.ones((3, 3), np.uint8), iterations=1)
    inpainted = cv2.inpaint(img, hair_mask, inpaintRadius=1, flags=cv2.INPAINT_TELEA)
    return inpainted

# %% [markdown]
# ## Apply LAB clahe preprocessing technique

# %%
def apply_clahe_lab(img):
    lab = cv2.cvtColor(img, cv2.COLOR_RGB2Lab)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    l_clahe = clahe.apply(l)
    lab_clahe = cv2.merge((l_clahe, a, b))
    img_clahe = cv2.cvtColor(lab_clahe, cv2.COLOR_Lab2RGB)
    return img_clahe

def augment_image(img):
    aug_imgs = []
    for angle in [90, 180, 270]:
        rotated = cv2.rotate(img, {
            90: cv2.ROTATE_90_CLOCKWISE,
            180: cv2.ROTATE_180,
            270: cv2.ROTATE_90_COUNTERCLOCKWISE
        }[angle])
        aug_imgs.append(rotated)
        aug_imgs.append(cv2.flip(rotated, 1))
    return aug_imgs

malignant_df = df[df["target"] == 1]
benign_df = df[df["target"] == 0].sample(n=10000, random_state=42)
df_filtered = pd.concat([malignant_df, benign_df]).reset_index(drop=True)

# %% [markdown]
# ## Experiment with different Preprocessing techniques

# %%
new_records = []

for _, row in tqdm(df_filtered.iterrows(), total=len(df_filtered)):
    isic_id = row["isic_id"]
    label = row["target"]
    img_path = os.path.join(image_dir, f"{isic_id}.jpg")
    save_path = os.path.join(save_dir, f"{isic_id}.jpg")
    
    img = cv2.imread(img_path)
    if img is None:
        continue
    
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))
    
    img = remove_hairs_dullrazor(img)
    img = apply_clahe_lab(img)
    
    cv2.imwrite(save_path, cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
    new_records.append({'isic_id': isic_id, 'target': label})
    

df_filtered = pd.DataFrame(new_records).reset_index(drop=True)

# %% [markdown]
# ## Define Dataset Class

# %%
class SkinLesionDataset(Dataset):
    def __init__(self, df, img_dir, transform=None):
        self.df = df
        self.img_dir = img_dir
        self.transform = transform
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        isic_id = self.df.iloc[idx]["isic_id"]
        label = self.df.iloc[idx]["target"]
        img_path = os.path.join(self.img_dir, f"{isic_id}.jpg")
        image = Image.open(img_path).convert("RGB")
        
        if self.transform:
            image = self.transform(image)
        
        return image, label

# %% [markdown]
# ## EfficientNet-B0 Binary Classifier Model

# %%
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
class EfficientNetBinaryClassifier(nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        weights = EfficientNet_B0_Weights.IMAGENET1K_V1 if pretrained else None
        self.backbone = efficientnet_b0(weights=weights)

        in_feats = self.backbone.classifier[1].in_features
        self.backbone.classifier = nn.Sequential(
            nn.Dropout(p=0.4, inplace=True),
            nn.Linear(in_feats, 1)
        )

    def forward(self, x):
        return self.backbone(x)

# %% [markdown]
# ## Full training loop

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    preds_list, labels_list = [], []
    
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device).float().unsqueeze(1)
        
        optimizer.zero_grad()
        logits = model(imgs)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * imgs.size(0)
        preds = torch.sigmoid(logits).detach().cpu().numpy() > 0.5
        preds_list.extend(preds.flatten())
        labels_list.extend(labels.cpu().numpy().flatten())
    
    avg_loss = running_loss / len(loader.dataset)
    acc = accuracy_score(labels_list, preds_list)
    return avg_loss, acc

def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    preds_list, labels_list = [], []
    
    with torch.no_grad():
        for imgs, labels in loader:
            imgs, labels = imgs.to(device), labels.to(device).float().unsqueeze(1)
            logits = model(imgs)
            loss = criterion(logits, labels)
            running_loss += loss.item() * imgs.size(0)
            
            preds = torch.sigmoid(logits).cpu().numpy() > 0.5
            preds_list.extend(preds.flatten())
            labels_list.extend(labels.cpu().numpy().flatten())
    
    avg_loss = running_loss / len(loader.dataset)
    acc = accuracy_score(labels_list, preds_list)
    return avg_loss, acc

# %% [markdown]
# ## K-fold Configuration

# %%
N_FOLDS = 5
EPOCHS_PER_FOLD = 20
BATCH_SIZE = 32
LEARNING_RATE = 2e-4

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(299, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((299, 299)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# ## K-Fold Cross Validation Loop

# %%
skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)
fold_results = []
best_models = []

print(f"\n{'='*70}")
print(f"Starting {N_FOLDS}-Fold Cross Validation")
print(f"{'='*70}\n")

for fold, (train_idx, val_idx) in enumerate(skf.split(df_filtered, df_filtered['target']), 1):
    print(f"\n{'='*70}")
    print(f"FOLD {fold}/{N_FOLDS}")
    print(f"{'='*70}")
    
    train_subset_df = df_filtered.iloc[train_idx].reset_index(drop=True)
    val_subset_df = df_filtered.iloc[val_idx].reset_index(drop=True)
    
    train_dataset = SkinLesionDataset(train_subset_df, save_dir, transform=train_transform)
    val_dataset = SkinLesionDataset(val_subset_df, save_dir, transform=val_transform)
    
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
    
    print(f"Train: {len(train_dataset)} | Val: {len(val_dataset)}")
    
    model = EfficientNetBinaryClassifier(pretrained=True).to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.8)
    
    best_val_acc = 0.0
    best_model_state = None
    val_acc_history = []
    
    for epoch in range(EPOCHS_PER_FOLD):
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_loss, val_acc = validate(model, val_loader, criterion, device)
    
        scheduler.step()
        val_acc_history.append(val_acc)
    
        print(f"Epoch {epoch+1}: "
              f"Train Loss = {train_loss:.4f}, Train Acc = {train_acc:.4f}, "
              f"Val Loss = {val_loss:.4f}, Val Acc = {val_acc:.4f}")
    
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model_state = copy.deepcopy(model.state_dict())
    
    fold_results.append({
        'fold': fold,
        'best_val_acc': best_val_acc,
        'val_acc_history': val_acc_history
    })
    
    best_models.append(best_model_state)
    print(f"\nFold {fold} Best Val Accuracy: {best_val_acc:.4f}")
# Out:
# ======================================================================
# Starting 5-Fold Cross Validation
# ======================================================================
#
#
# ======================================================================
# FOLD 1/5
# ======================================================================
# Train: 10200 | Val: 2551
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 141MB/s]
# Epoch 1: Train Loss = 0.3210, Train Acc = 0.8675, Val Loss = 0.2261, Val Acc = 0.9091
# Epoch 2: Train Loss = 0.2256, Train Acc = 0.9068, Val Loss = 0.2073, Val Acc = 0.9059
# Epoch 3: Train Loss = 0.1802, Train Acc = 0.9266, Val Loss = 0.1478, Val Acc = 0.9428
# Epoch 4: Train Loss = 0.1338, Train Acc = 0.9468, Val Loss = 0.1204, Val Acc = 0.9498
# Epoch 5: Train Loss = 0.1115, Train Acc = 0.9579, Val Loss = 0.1085, Val Acc = 0.9608
# Epoch 6: Train Loss = 0.0899, Train Acc = 0.9655, Val Loss = 0.1244, Val Acc = 0.9534
# Epoch 7: Train Loss = 0.0692, Train Acc = 0.9741, Val Loss = 0.0784, Val Acc = 0.9675
# Epoch 8: Train Loss = 0.0544, Train Acc = 0.9792, Val Loss = 0.0984, Val Acc = 0.9675
# Epoch 9: Train Loss = 0.0453, Train Acc = 0.9830, Val Loss = 0.0729, Val Acc = 0.9749
# Epoch 10: Train Loss = 0.0346, Train Acc = 0.9883, Val Loss = 0.0714, Val Acc = 0.9769
# Epoch 11: Train Loss = 0.0321, Train Acc = 0.9885, Val Loss = 0.0795, Val Acc = 0.9769
# Epoch 12: Train Loss = 0.0259, Train Acc = 0.9902, Val Loss = 0.0882, Val Acc = 0.9733
# Epoch 13: Train Loss = 0.0204, Train Acc = 0.9930, Val Loss = 0.0822, Val Acc = 0.9757
# Epoch 14: Train Loss = 0.0238, Train Acc = 0.9916, Val Loss = 0.0716, Val Acc = 0.9780
# Epoch 15: Train Loss = 0.0186, Train Acc = 0.9940, Val Loss = 0.0906, Val Acc = 0.9733
# Epoch 16: Train Loss = 0.0181, Train Acc = 0.9932, Val Loss = 0.1006, Val Acc = 0.9730
# Epoch 17: Train Loss = 0.0114, Train Acc = 0.9960, Val Loss = 0.0828, Val Acc = 0.9765
# Epoch 18: Train Loss = 0.0157, Train Acc = 0.9954, Val Loss = 0.0964, Val Acc = 0.9730
# Epoch 19: Train Loss = 0.0145, Train Acc = 0.9954, Val Loss = 0.0706, Val Acc = 0.9788
# Epoch 20: Train Loss = 0.0148, Train Acc = 0.9951, Val Loss = 0.0906, Val Acc = 0.9741
#
# Fold 1 Best Val Accuracy: 0.9788
#
# ======================================================================
# FOLD 2/5
# ======================================================================
# Train: 10201 | Val: 2550
# Epoch 1: Train Loss = 0.3143, Train Acc = 0.8690, Val Loss = 0.2295, Val Acc = 0.8992
# Epoch 2: Train Loss = 0.2315, Train Acc = 0.8998, Val Loss = 0.2134, Val Acc = 0.9039
# Epoch 3: Train Loss = 0.1827, Train Acc = 0.9248, Val Loss = 0.1674, Val Acc = 0.9310
# Epoch 4: Train Loss = 0.1446, Train Acc = 0.9408, Val Loss = 0.1483, Val Acc = 0.9373
# Epoch 5: Train Loss = 0.1121, Train Acc = 0.9556, Val Loss = 0.1126, Val Acc = 0.9549
# Epoch 6: Train Loss = 0.0824, Train Acc = 0.9673, Val Loss = 0.0979, Val Acc = 0.9608
# Epoch 7: Train Loss = 0.0690, Train Acc = 0.9733, Val Loss = 0.1022, Val Acc = 0.9612
# Epoch 8: Train Loss = 0.0579, Train Acc = 0.9789, Val Loss = 0.0732, Val Acc = 0.9725
# Epoch 9: Train Loss = 0.0477, Train Acc = 0.9823, Val Loss = 0.0855, Val Acc = 0.9710
# Epoch 10: Train Loss = 0.0374, Train Acc = 0.9867, Val Loss = 0.0838, Val Acc = 0.9722
# Epoch 11: Train Loss = 0.0311, Train Acc = 0.9892, Val Loss = 0.1038, Val Acc = 0.9671
# Epoch 12: Train Loss = 0.0296, Train Acc = 0.9900, Val Loss = 0.0737, Val Acc = 0.9757
# Epoch 13: Train Loss = 0.0250, Train Acc = 0.9906, Val Loss = 0.0888, Val Acc = 0.9714
# Epoch 14: Train Loss = 0.0212, Train Acc = 0.9927, Val Loss = 0.0646, Val Acc = 0.9800
# Epoch 15: Train Loss = 0.0161, Train Acc = 0.9949, Val Loss = 0.0685, Val Acc = 0.9780
# Epoch 16: Train Loss = 0.0192, Train Acc = 0.9926, Val Loss = 0.0644, Val Acc = 0.9792
# Epoch 17: Train Loss = 0.0132, Train Acc = 0.9957, Val Loss = 0.0712, Val Acc = 0.9780
# Epoch 18: Train Loss = 0.0161, Train Acc = 0.9947, Val Loss = 0.0650, Val Acc = 0.9788
# Epoch 19: Train Loss = 0.0112, Train Acc = 0.9960, Val Loss = 0.0569, Val Acc = 0.9816
# Epoch 20: Train Loss = 0.0091, Train Acc = 0.9968, Val Loss = 0.0888, Val Acc = 0.9765
#
# Fold 2 Best Val Accuracy: 0.9816
#
# ======================================================================
# FOLD 3/5
# ======================================================================
# Train: 10201 | Val: 2550
# Epoch 1: Train Loss = 0.3263, Train Acc = 0.8632, Val Loss = 0.2391, Val Acc = 0.8878
# Epoch 2: Train Loss = 0.2304, Train Acc = 0.9030, Val Loss = 0.1831, Val Acc = 0.9196
# Epoch 3: Train Loss = 0.1843, Train Acc = 0.9227, Val Loss = 0.1459, Val Acc = 0.9404
# Epoch 4: Train Loss = 0.1377, Train Acc = 0.9487, Val Loss = 0.1152, Val Acc = 0.9561
# Epoch 5: Train Loss = 0.1068, Train Acc = 0.9596, Val Loss = 0.0986, Val Acc = 0.9600
# Epoch 6: Train Loss = 0.0897, Train Acc = 0.9661, Val Loss = 0.1017, Val Acc = 0.9565
# Epoch 7: Train Loss = 0.0625, Train Acc = 0.9776, Val Loss = 0.0866, Val Acc = 0.9694
# Epoch 8: Train Loss = 0.0539, Train Acc = 0.9803, Val Loss = 0.0773, Val Acc = 0.9733
# Epoch 9: Train Loss = 0.0514, Train Acc = 0.9801, Val Loss = 0.0841, Val Acc = 0.9718
# Epoch 10: Train Loss = 0.0344, Train Acc = 0.9880, Val Loss = 0.0710, Val Acc = 0.9753
# Epoch 11: Train Loss = 0.0288, Train Acc = 0.9898, Val Loss = 0.0962, Val Acc = 0.9675
# Epoch 12: Train Loss = 0.0308, Train Acc = 0.9878, Val Loss = 0.0560, Val Acc = 0.9780
# Epoch 13: Train Loss = 0.0214, Train Acc = 0.9927, Val Loss = 0.0871, Val Acc = 0.9749
# Epoch 14: Train Loss = 0.0240, Train Acc = 0.9914, Val Loss = 0.0953, Val Acc = 0.9690
# Epoch 15: Train Loss = 0.0181, Train Acc = 0.9946, Val Loss = 0.0588, Val Acc = 0.9816
# Epoch 16: Train Loss = 0.0166, Train Acc = 0.9944, Val Loss = 0.0657, Val Acc = 0.9796
# Epoch 17: Train Loss = 0.0134, Train Acc = 0.9951, Val Loss = 0.0625, Val Acc = 0.9824
# Epoch 18: Train Loss = 0.0097, Train Acc = 0.9967, Val Loss = 0.0578, Val Acc = 0.9824
# Epoch 19: Train Loss = 0.0094, Train Acc = 0.9970, Val Loss = 0.0673, Val Acc = 0.9812
# Epoch 20: Train Loss = 0.0074, Train Acc = 0.9980, Val Loss = 0.0487, Val Acc = 0.9871
#
# Fold 3 Best Val Accuracy: 0.9871
#
# ======================================================================
# FOLD 4/5
# ======================================================================
# Train: 10201 | Val: 2550
# Epoch 1: Train Loss = 0.3188, Train Acc = 0.8660, Val Loss = 0.2383, Val Acc = 0.8996
# Epoch 2: Train Loss = 0.2355, Train Acc = 0.9025, Val Loss = 0.2135, Val Acc = 0.9012
# Epoch 3: Train Loss = 0.1931, Train Acc = 0.9203, Val Loss = 0.1576, Val Acc = 0.9325
# Epoch 4: Train Loss = 0.1467, Train Acc = 0.9408, Val Loss = 0.1402, Val Acc = 0.9463
# Epoch 5: Train Loss = 0.1196, Train Acc = 0.9535, Val Loss = 0.1101, Val Acc = 0.9537
# Epoch 6: Train Loss = 0.0959, Train Acc = 0.9626, Val Loss = 0.0992, Val Acc = 0.9569
# Epoch 7: Train Loss = 0.0726, Train Acc = 0.9731, Val Loss = 0.0769, Val Acc = 0.9702
# Epoch 8: Train Loss = 0.0655, Train Acc = 0.9758, Val Loss = 0.0896, Val Acc = 0.9671
# Epoch 9: Train Loss = 0.0544, Train Acc = 0.9805, Val Loss = 0.0653, Val Acc = 0.9769
# Epoch 10: Train Loss = 0.0376, Train Acc = 0.9872, Val Loss = 0.0731, Val Acc = 0.9749
# Epoch 11: Train Loss = 0.0324, Train Acc = 0.9885, Val Loss = 0.0990, Val Acc = 0.9667
# Epoch 12: Train Loss = 0.0266, Train Acc = 0.9912, Val Loss = 0.0600, Val Acc = 0.9804
# Epoch 13: Train Loss = 0.0252, Train Acc = 0.9912, Val Loss = 0.0620, Val Acc = 0.9788
# Epoch 14: Train Loss = 0.0246, Train Acc = 0.9915, Val Loss = 0.0589, Val Acc = 0.9800
# Epoch 15: Train Loss = 0.0191, Train Acc = 0.9933, Val Loss = 0.0676, Val Acc = 0.9792
# Epoch 16: Train Loss = 0.0143, Train Acc = 0.9951, Val Loss = 0.0701, Val Acc = 0.9765
# Epoch 17: Train Loss = 0.0149, Train Acc = 0.9947, Val Loss = 0.0578, Val Acc = 0.9804
# Epoch 18: Train Loss = 0.0141, Train Acc = 0.9951, Val Loss = 0.0739, Val Acc = 0.9757
# Epoch 19: Train Loss = 0.0098, Train Acc = 0.9974, Val Loss = 0.0605, Val Acc = 0.9820
# Epoch 20: Train Loss = 0.0130, Train Acc = 0.9950, Val Loss = 0.0655, Val Acc = 0.9788
#
# Fold 4 Best Val Accuracy: 0.9820
#
# ======================================================================
# FOLD 5/5
# ======================================================================
# Train: 10201 | Val: 2550
# Epoch 1: Train Loss = 0.3260, Train Acc = 0.8652, Val Loss = 0.2372, Val Acc = 0.9090
# Epoch 2: Train Loss = 0.2354, Train Acc = 0.9002, Val Loss = 0.2258, Val Acc = 0.9027
# Epoch 3: Train Loss = 0.1905, Train Acc = 0.9179, Val Loss = 0.1716, Val Acc = 0.9353
# Epoch 4: Train Loss = 0.1352, Train Acc = 0.9484, Val Loss = 0.1263, Val Acc = 0.9514
# Epoch 5: Train Loss = 0.1173, Train Acc = 0.9548, Val Loss = 0.1319, Val Acc = 0.9459
# Epoch 6: Train Loss = 0.0911, Train Acc = 0.9639, Val Loss = 0.1161, Val Acc = 0.9612
# Epoch 7: Train Loss = 0.0655, Train Acc = 0.9761, Val Loss = 0.0758, Val Acc = 0.9745
# Epoch 8: Train Loss = 0.0600, Train Acc = 0.9765, Val Loss = 0.0845, Val Acc = 0.9690
# Epoch 9: Train Loss = 0.0474, Train Acc = 0.9830, Val Loss = 0.0716, Val Acc = 0.9745
# Epoch 10: Train Loss = 0.0368, Train Acc = 0.9869, Val Loss = 0.0621, Val Acc = 0.9820
# Epoch 11: Train Loss = 0.0292, Train Acc = 0.9900, Val Loss = 0.0751, Val Acc = 0.9769
# Epoch 12: Train Loss = 0.0326, Train Acc = 0.9876, Val Loss = 0.0957, Val Acc = 0.9702
# Epoch 13: Train Loss = 0.0213, Train Acc = 0.9922, Val Loss = 0.0677, Val Acc = 0.9824
# Epoch 14: Train Loss = 0.0192, Train Acc = 0.9938, Val Loss = 0.0557, Val Acc = 0.9831
# Epoch 15: Train Loss = 0.0177, Train Acc = 0.9941, Val Loss = 0.0613, Val Acc = 0.9843
# Epoch 16: Train Loss = 0.0116, Train Acc = 0.9961, Val Loss = 0.0775, Val Acc = 0.9773
# Epoch 17: Train Loss = 0.0149, Train Acc = 0.9948, Val Loss = 0.0688, Val Acc = 0.9820
# Epoch 18: Train Loss = 0.0144, Train Acc = 0.9952, Val Loss = 0.0758, Val Acc = 0.9816
# Epoch 19: Train Loss = 0.0111, Train Acc = 0.9964, Val Loss = 0.0712, Val Acc = 0.9816
# Epoch 20: Train Loss = 0.0091, Train Acc = 0.9967, Val Loss = 0.0725, Val Acc = 0.9839
#
# Fold 5 Best Val Accuracy: 0.9843

# %% [markdown]
# ## Results Summary

# %%
print("K-FOLD RESULTS SUMMARY")

results_df = pd.DataFrame(fold_results)
print(results_df)

print(f"\nAverage Val Accuracy: {results_df['best_val_acc'].mean():.4f} ± {results_df['best_val_acc'].std():.4f}")

best_fold_idx = results_df['best_val_acc'].idxmax()
print(f"\nBest Fold: {results_df.iloc[best_fold_idx]['fold']} with accuracy {results_df.iloc[best_fold_idx]['best_val_acc']:.4f}")

torch.save(best_models[best_fold_idx], 'best_kfold_model.pth')
# Out:
# K-FOLD RESULTS SUMMARY
#    fold  best_val_acc                                    val_acc_history
# 0     1      0.978832  [0.9090552724421795, 0.9059192473539789, 0.942...
# 1     2      0.981569  [0.8992156862745098, 0.903921568627451, 0.9309...
# 2     3      0.987059  [0.8878431372549019, 0.9196078431372549, 0.940...
# 3     4      0.981961  [0.899607843137255, 0.9011764705882352, 0.9325...
# 4     5      0.984314  [0.9090196078431373, 0.9027450980392157, 0.935...
#
# Average Val Accuracy: 0.9827 ± 0.0031
#
# Best Fold: 3 with accuracy 0.9871

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(10, 6))
colors = ['r', 'g', 'b', 'orange', 'purple']

for i, fold_data in enumerate(fold_results):
    plt.plot(range(1, len(fold_data['val_acc_history']) + 1),
             fold_data['val_acc_history'],
             label=f"Fold {fold_data['fold']}",
             color=colors[i % len(colors)],
             linewidth=2)

plt.title("Validation Accuracy Change per Epoch (All 5 Folds)", fontsize=14, fontweight='bold')
plt.xlabel("Epoch", fontsize=12, fontweight='bold')
plt.ylabel("Validation Accuracy", fontsize=12, fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
