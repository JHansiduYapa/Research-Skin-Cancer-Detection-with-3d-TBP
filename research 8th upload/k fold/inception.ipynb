# %% [markdown]
# ## Import libraries & set random seed

# %%
import numpy as np
import pandas as pd
import os
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from PIL import Image
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import matplotlib.pyplot as plt
import warnings
import copy
warnings.filterwarnings('ignore')

manualSeed = 999
np.random.seed(manualSeed)
torch.manual_seed(manualSeed)
print("Random Seed:", manualSeed)

image_dir = '/kaggle/input/isic-2024-challenge/train-image/image'
meta_dir = "/kaggle/input/isic-2024-challenge/"
save_dir = '/kaggle/working/processed_images'
os.makedirs(save_dir, exist_ok=True)

image_files = os.listdir(image_dir)[:10]

for i, file_name in enumerate(image_files, 1):
    image_path = os.path.join(image_dir, file_name)
    with Image.open(image_path) as img:
        print(f"Image {i}: {file_name} - Size: {img.size}")
# Out:
# Random Seed: 999
# Image 1: ISIC_9730802.jpg - Size: (139, 139)
# Image 2: ISIC_2834883.jpg - Size: (125, 125)
# Image 3: ISIC_5115027.jpg - Size: (123, 123)
# Image 4: ISIC_3264822.jpg - Size: (115, 115)
# Image 5: ISIC_1950204.jpg - Size: (147, 147)
# Image 6: ISIC_8411738.jpg - Size: (145, 145)
# Image 7: ISIC_3744117.jpg - Size: (133, 133)
# Image 8: ISIC_0989720.jpg - Size: (131, 131)
# Image 9: ISIC_3926794.jpg - Size: (139, 139)
# Image 10: ISIC_2892810.jpg - Size: (107, 107)

# %% [markdown]
# ## Load & Filter Data

# %%
df = pd.read_csv(meta_dir + "train-metadata.csv")

malignant_df = df[df["target"] == 1]
benign_df = df[df["target"] == 0].sample(n=10000, random_state=42)
df_filtered = pd.concat([malignant_df, benign_df]).reset_index(drop=True)

# %% [markdown]
# ## Apply Hair Removal preprocessing technique function (DullRazor)

# %%
def remove_hairs_dullrazor(img):
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (9, 9))
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)
    _, hair_mask = cv2.threshold(blackhat, 10, 255, cv2.THRESH_BINARY)
    hair_mask = cv2.dilate(hair_mask, np.ones((3, 3), np.uint8), iterations=1)
    inpainted = cv2.inpaint(img, hair_mask, inpaintRadius=1, flags=cv2.INPAINT_TELEA)
    return inpainted

# %% [markdown]
# ## Apply LAB clahe preprocessing technique

# %%
def apply_clahe_lab(img):
    lab = cv2.cvtColor(img, cv2.COLOR_RGB2Lab)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    l_clahe = clahe.apply(l)
    lab_clahe = cv2.merge((l_clahe, a, b))
    img_clahe = cv2.cvtColor(lab_clahe, cv2.COLOR_Lab2RGB)
    return img_clahe

def augment_image(img):
    aug_imgs = []
    for angle in [90, 180, 270]:
        rotated = cv2.rotate(img, {
            90: cv2.ROTATE_90_CLOCKWISE,
            180: cv2.ROTATE_180,
            270: cv2.ROTATE_90_COUNTERCLOCKWISE
        }[angle])
        aug_imgs.append(rotated)
        aug_imgs.append(cv2.flip(rotated, 1))
    return aug_imgs

malignant_df = df[df["target"] == 1]
benign_df = df[df["target"] == 0].sample(n=10000, random_state=42)
df_filtered = pd.concat([malignant_df, benign_df]).reset_index(drop=True)

# %% [markdown]
# ## Experiment with different Preprocessing techniques

# %%
new_records = []

for _, row in tqdm(df_filtered.iterrows(), total=len(df_filtered)):
    isic_id = row["isic_id"]
    label = row["target"]
    img_path = os.path.join(image_dir, f"{isic_id}.jpg")
    save_path = os.path.join(save_dir, f"{isic_id}.jpg")
    
    img = cv2.imread(img_path)
    if img is None:
        continue
    
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))
    
    img = remove_hairs_dullrazor(img)
    img = apply_clahe_lab(img)
    
    cv2.imwrite(save_path, cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
    new_records.append({'isic_id': isic_id, 'target': label})
    
    if label == 1:
        aug_imgs = augment_image(img)
        for i, aug_img in enumerate(aug_imgs):
            aug_id = f"{isic_id}_aug{i}"
            aug_path = os.path.join(save_dir, f"{aug_id}.jpg")
            cv2.imwrite(aug_path, cv2.cvtColor(aug_img, cv2.COLOR_RGB2BGR))
            new_records.append({'isic_id': aug_id, 'target': 1})

df_filtered = pd.DataFrame(new_records).reset_index(drop=True)

# %% [markdown]
# ## Dataset Class Definition

# %%
class SkinLesionDataset(Dataset):
    def __init__(self, df, img_dir, transform=None):
        self.df = df
        self.img_dir = img_dir
        self.transform = transform
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        isic_id = self.df.iloc[idx]["isic_id"]
        label = self.df.iloc[idx]["target"]
        img_path = os.path.join(self.img_dir, f"{isic_id}.jpg")
        image = Image.open(img_path).convert("RGB")
        
        if self.transform:
            image = self.transform(image)
        
        return image, label

# %% [markdown]
# ##  InceptionV3 Binary Classifier Model

# %%
from torchvision.models import inception_v3, Inception_V3_Weights
import torch.nn as nn

class InceptionV3BinaryClassifier(nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()

        try:
            weights = Inception_V3_Weights.IMAGENET1K_V1 if pretrained else None
            self.backbone = inception_v3(weights=weights, aux_logits=True)
            print(f"✅ InceptionV3 backbone loaded (pretrained={pretrained})")
        except Exception as e:
            print(f"⚠️ Could not load pretrained weights, initializing randomly. Error: {e}")
            self.backbone = inception_v3(weights=None, aux_logits=True)

        in_feats = self.backbone.fc.in_features
        self.backbone.fc = nn.Sequential(
            nn.Linear(in_feats, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, 1)
        )

    def forward(self, x):
        out = self.backbone(x)
        if isinstance(out, tuple):
            out = out[0]
        return out

# %% [markdown]
# ## Full training loop

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    preds_list, labels_list = [], []

    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device).float().unsqueeze(1)

        optimizer.zero_grad()
        outputs = model(imgs)

        if isinstance(outputs, tuple):
            logits, aux_logits = outputs
            loss1 = criterion(logits, labels)
            loss2 = criterion(aux_logits, labels)
            loss = loss1 + 0.4 * loss2
        else:
            logits = outputs
            loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * imgs.size(0)
        preds = (torch.sigmoid(logits).detach().cpu().numpy() > 0.5).astype(int)
        preds_list.extend(preds.flatten())
        labels_list.extend(labels.cpu().numpy().flatten())

    avg_loss = running_loss / len(loader.dataset)
    acc = accuracy_score(labels_list, preds_list)
    return avg_loss, acc


def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    preds_list, labels_list = [], []

    with torch.no_grad():
        for imgs, labels in loader:
            imgs, labels = imgs.to(device), labels.to(device).float().unsqueeze(1)
            outputs = model(imgs)

            # Handle tuple (main, aux) just in case
            if isinstance(outputs, tuple):
                logits = outputs[0]
            else:
                logits = outputs

            loss = criterion(logits, labels)
            running_loss += loss.item() * imgs.size(0)

            preds = (torch.sigmoid(logits).cpu().numpy() > 0.5).astype(int)
            preds_list.extend(preds.flatten())
            labels_list.extend(labels.cpu().numpy().flatten())

    avg_loss = running_loss / len(loader.dataset)
    acc = accuracy_score(labels_list, preds_list)
    return avg_loss, acc

# %% [markdown]
# ## K-fold configuration

# %%
N_FOLDS = 5
EPOCHS_PER_FOLD = 20
BATCH_SIZE = 32
LEARNING_RATE = 2e-4

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(299, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((299, 299)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# ## K-Fold Cross Validation Loop

# %%
skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)
fold_results = []
best_models = []

print(f"\n{'='*70}")
print(f"Starting {N_FOLDS}-Fold Cross Validation")
print(f"{'='*70}\n")

for fold, (train_idx, val_idx) in enumerate(skf.split(df_filtered, df_filtered['target']), 1):
    print(f"\n{'='*70}")
    print(f"FOLD {fold}/{N_FOLDS}")
    print(f"{'='*70}")

    train_subset_df = df_filtered.iloc[train_idx].reset_index(drop=True)
    val_subset_df = df_filtered.iloc[val_idx].reset_index(drop=True)

    train_dataset = SkinLesionDataset(train_subset_df, save_dir, transform=train_transform)
    val_dataset = SkinLesionDataset(val_subset_df, save_dir, transform=val_transform)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

    model = InceptionV3BinaryClassifier(pretrained=True).to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.8)

    best_val_acc = 0.0
    best_model_state = None
    val_acc_history = []

    for epoch in range(EPOCHS_PER_FOLD):
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_loss, val_acc = validate(model, val_loader, criterion, device)

        scheduler.step()
        val_acc_history.append(val_acc)

        print(f"Epoch {epoch+1}: "
              f"Train Loss = {train_loss:.4f}, Train Acc = {train_acc:.4f}, "
              f"Val Loss = {val_loss:.4f}, Val Acc = {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model_state = copy.deepcopy(model.state_dict())

    fold_results.append({
        'fold': fold,
        'best_val_acc': best_val_acc,
        'val_acc_history': val_acc_history
    })

    best_models.append(best_model_state)
    print(f"\nFold {fold} Best Val Accuracy: {best_val_acc:.4f}")
# Out:
# ======================================================================
# Starting 5-Fold Cross Validation
# ======================================================================
#
#
# ======================================================================
# FOLD 1/5
# ======================================================================
# ✅ InceptionV3 backbone loaded (pretrained=True)
# Epoch 1: Train Loss = 0.4708, Train Acc = 0.8609, Val Loss = 0.2591, Val Acc = 0.8957
# Epoch 2: Train Loss = 0.3602, Train Acc = 0.8930, Val Loss = 0.2277, Val Acc = 0.9044
# Epoch 3: Train Loss = 0.3154, Train Acc = 0.9068, Val Loss = 0.2281, Val Acc = 0.9044
# Epoch 4: Train Loss = 0.2523, Train Acc = 0.9225, Val Loss = 0.2191, Val Acc = 0.9267
# Epoch 5: Train Loss = 0.2167, Train Acc = 0.9375, Val Loss = 0.1604, Val Acc = 0.9381
# Epoch 6: Train Loss = 0.1802, Train Acc = 0.9495, Val Loss = 0.1706, Val Acc = 0.9330
# Epoch 7: Train Loss = 0.1327, Train Acc = 0.9660, Val Loss = 0.1395, Val Acc = 0.9526
# Epoch 8: Train Loss = 0.1023, Train Acc = 0.9739, Val Loss = 0.1342, Val Acc = 0.9522
# Epoch 9: Train Loss = 0.1058, Train Acc = 0.9719, Val Loss = 0.1560, Val Acc = 0.9522
# Epoch 10: Train Loss = 0.0746, Train Acc = 0.9823, Val Loss = 0.1372, Val Acc = 0.9565
# Epoch 11: Train Loss = 0.0685, Train Acc = 0.9831, Val Loss = 0.1243, Val Acc = 0.9632
# Epoch 12: Train Loss = 0.0634, Train Acc = 0.9858, Val Loss = 0.1156, Val Acc = 0.9569
# Epoch 13: Train Loss = 0.0412, Train Acc = 0.9907, Val Loss = 0.1155, Val Acc = 0.9690
# Epoch 14: Train Loss = 0.0336, Train Acc = 0.9920, Val Loss = 0.1220, Val Acc = 0.9694
# Epoch 15: Train Loss = 0.0439, Train Acc = 0.9900, Val Loss = 0.1297, Val Acc = 0.9651
# Epoch 16: Train Loss = 0.0232, Train Acc = 0.9943, Val Loss = 0.1357, Val Acc = 0.9651
# Epoch 17: Train Loss = 0.0252, Train Acc = 0.9938, Val Loss = 0.1395, Val Acc = 0.9647
# Epoch 18: Train Loss = 0.0257, Train Acc = 0.9943, Val Loss = 0.1394, Val Acc = 0.9671
# Epoch 19: Train Loss = 0.0150, Train Acc = 0.9970, Val Loss = 0.1550, Val Acc = 0.9675
# Epoch 20: Train Loss = 0.0205, Train Acc = 0.9954, Val Loss = 0.0955, Val Acc = 0.9769
#
# Fold 1 Best Val Accuracy: 0.9769
#
# ======================================================================
# FOLD 2/5
# ======================================================================
# ✅ InceptionV3 backbone loaded (pretrained=True)
# Epoch 1: Train Loss = 0.4713, Train Acc = 0.8578, Val Loss = 0.2838, Val Acc = 0.8827
# Epoch 2: Train Loss = 0.3731, Train Acc = 0.8892, Val Loss = 0.2716, Val Acc = 0.8941
# Epoch 3: Train Loss = 0.3238, Train Acc = 0.9042, Val Loss = 0.2388, Val Acc = 0.9012
# Epoch 4: Train Loss = 0.2535, Train Acc = 0.9264, Val Loss = 0.2586, Val Acc = 0.8941
# Epoch 5: Train Loss = 0.2184, Train Acc = 0.9385, Val Loss = 0.2151, Val Acc = 0.9227
# Epoch 6: Train Loss = 0.1775, Train Acc = 0.9514, Val Loss = 0.1911, Val Acc = 0.9306
# Epoch 7: Train Loss = 0.1401, Train Acc = 0.9634, Val Loss = 0.1216, Val Acc = 0.9545
# Epoch 8: Train Loss = 0.1151, Train Acc = 0.9697, Val Loss = 0.1216, Val Acc = 0.9545
# Epoch 9: Train Loss = 0.0976, Train Acc = 0.9750, Val Loss = 0.1281, Val Acc = 0.9604
# Epoch 10: Train Loss = 0.0719, Train Acc = 0.9822, Val Loss = 0.1156, Val Acc = 0.9655
# Epoch 11: Train Loss = 0.0618, Train Acc = 0.9842, Val Loss = 0.1519, Val Acc = 0.9502
# Epoch 12: Train Loss = 0.0573, Train Acc = 0.9859, Val Loss = 0.1292, Val Acc = 0.9592
# Epoch 13: Train Loss = 0.0455, Train Acc = 0.9890, Val Loss = 0.1184, Val Acc = 0.9663
# Epoch 14: Train Loss = 0.0380, Train Acc = 0.9911, Val Loss = 0.1303, Val Acc = 0.9659
# Epoch 15: Train Loss = 0.0394, Train Acc = 0.9906, Val Loss = 0.1311, Val Acc = 0.9667
# Epoch 16: Train Loss = 0.0188, Train Acc = 0.9960, Val Loss = 0.1881, Val Acc = 0.9596
# Epoch 17: Train Loss = 0.0232, Train Acc = 0.9951, Val Loss = 0.1104, Val Acc = 0.9718
# Epoch 18: Train Loss = 0.0237, Train Acc = 0.9949, Val Loss = 0.1225, Val Acc = 0.9718
# Epoch 19: Train Loss = 0.0154, Train Acc = 0.9968, Val Loss = 0.1094, Val Acc = 0.9729
# Epoch 20: Train Loss = 0.0210, Train Acc = 0.9951, Val Loss = 0.1163, Val Acc = 0.9706
#
# Fold 2 Best Val Accuracy: 0.9729
#
# ======================================================================
# FOLD 3/5
# ======================================================================
# ✅ InceptionV3 backbone loaded (pretrained=True)
# Epoch 1: Train Loss = 0.4785, Train Acc = 0.8526, Val Loss = 0.2596, Val Acc = 0.8922
# Epoch 2: Train Loss = 0.3743, Train Acc = 0.8879, Val Loss = 0.2223, Val Acc = 0.9024
# Epoch 3: Train Loss = 0.3370, Train Acc = 0.8986, Val Loss = 0.2049, Val Acc = 0.9106
# Epoch 4: Train Loss = 0.2615, Train Acc = 0.9210, Val Loss = 0.1819, Val Acc = 0.9204
# Epoch 5: Train Loss = 0.2257, Train Acc = 0.9367, Val Loss = 0.1811, Val Acc = 0.9337
# Epoch 6: Train Loss = 0.1960, Train Acc = 0.9434, Val Loss = 0.1504, Val Acc = 0.9400
# Epoch 7: Train Loss = 0.1439, Train Acc = 0.9626, Val Loss = 0.1220, Val Acc = 0.9545
# Epoch 8: Train Loss = 0.1251, Train Acc = 0.9682, Val Loss = 0.1593, Val Acc = 0.9459
# Epoch 9: Train Loss = 0.1043, Train Acc = 0.9741, Val Loss = 0.0970, Val Acc = 0.9655
# Epoch 10: Train Loss = 0.0815, Train Acc = 0.9798, Val Loss = 0.1451, Val Acc = 0.9416
# Epoch 11: Train Loss = 0.0589, Train Acc = 0.9861, Val Loss = 0.0962, Val Acc = 0.9682
# Epoch 12: Train Loss = 0.0610, Train Acc = 0.9844, Val Loss = 0.1073, Val Acc = 0.9671
# Epoch 13: Train Loss = 0.0417, Train Acc = 0.9902, Val Loss = 0.1037, Val Acc = 0.9690
# Epoch 14: Train Loss = 0.0452, Train Acc = 0.9891, Val Loss = 0.1190, Val Acc = 0.9647
# Epoch 15: Train Loss = 0.0351, Train Acc = 0.9923, Val Loss = 0.1265, Val Acc = 0.9627
# Epoch 16: Train Loss = 0.0293, Train Acc = 0.9936, Val Loss = 0.1031, Val Acc = 0.9682
# Epoch 17: Train Loss = 0.0257, Train Acc = 0.9940, Val Loss = 0.0947, Val Acc = 0.9686
# Epoch 18: Train Loss = 0.0254, Train Acc = 0.9935, Val Loss = 0.0785, Val Acc = 0.9776
# Epoch 19: Train Loss = 0.0202, Train Acc = 0.9958, Val Loss = 0.0927, Val Acc = 0.9784
# Epoch 20: Train Loss = 0.0143, Train Acc = 0.9968, Val Loss = 0.1019, Val Acc = 0.9729
#
# Fold 3 Best Val Accuracy: 0.9784
#
# ======================================================================
# FOLD 4/5
# ======================================================================
# ✅ InceptionV3 backbone loaded (pretrained=True)
# Epoch 1: Train Loss = 0.4764, Train Acc = 0.8592, Val Loss = 0.2592, Val Acc = 0.8937
# Epoch 2: Train Loss = 0.3700, Train Acc = 0.8912, Val Loss = 0.2701, Val Acc = 0.8878
# Epoch 3: Train Loss = 0.3268, Train Acc = 0.9023, Val Loss = 0.2137, Val Acc = 0.9122
# Epoch 4: Train Loss = 0.2536, Train Acc = 0.9246, Val Loss = 0.1992, Val Acc = 0.9125
# Epoch 5: Train Loss = 0.2096, Train Acc = 0.9411, Val Loss = 0.2293, Val Acc = 0.9067
# Epoch 6: Train Loss = 0.1834, Train Acc = 0.9513, Val Loss = 0.1852, Val Acc = 0.9341
# Epoch 7: Train Loss = 0.1384, Train Acc = 0.9618, Val Loss = 0.1784, Val Acc = 0.9349
# Epoch 8: Train Loss = 0.1120, Train Acc = 0.9694, Val Loss = 0.1573, Val Acc = 0.9455
# Epoch 9: Train Loss = 0.1080, Train Acc = 0.9711, Val Loss = 0.1362, Val Acc = 0.9553
# Epoch 10: Train Loss = 0.0727, Train Acc = 0.9807, Val Loss = 0.1289, Val Acc = 0.9565
# Epoch 11: Train Loss = 0.0742, Train Acc = 0.9808, Val Loss = 0.1162, Val Acc = 0.9588
# Epoch 12: Train Loss = 0.0556, Train Acc = 0.9867, Val Loss = 0.1208, Val Acc = 0.9592
# Epoch 13: Train Loss = 0.0503, Train Acc = 0.9893, Val Loss = 0.1093, Val Acc = 0.9608
# Epoch 14: Train Loss = 0.0408, Train Acc = 0.9906, Val Loss = 0.1396, Val Acc = 0.9573
# Epoch 15: Train Loss = 0.0396, Train Acc = 0.9898, Val Loss = 0.1499, Val Acc = 0.9569
# Epoch 16: Train Loss = 0.0361, Train Acc = 0.9917, Val Loss = 0.1003, Val Acc = 0.9686
# Epoch 17: Train Loss = 0.0237, Train Acc = 0.9953, Val Loss = 0.1104, Val Acc = 0.9655
# Epoch 18: Train Loss = 0.0206, Train Acc = 0.9951, Val Loss = 0.1171, Val Acc = 0.9667
# Epoch 19: Train Loss = 0.0185, Train Acc = 0.9962, Val Loss = 0.1182, Val Acc = 0.9733
# Epoch 20: Train Loss = 0.0157, Train Acc = 0.9966, Val Loss = 0.1336, Val Acc = 0.9667
#
# Fold 4 Best Val Accuracy: 0.9733
#
# ======================================================================
# FOLD 5/5
# ======================================================================
# ✅ InceptionV3 backbone loaded (pretrained=True)
# Epoch 1: Train Loss = 0.4659, Train Acc = 0.8590, Val Loss = 0.2642, Val Acc = 0.9008
# Epoch 2: Train Loss = 0.3662, Train Acc = 0.8909, Val Loss = 0.2046, Val Acc = 0.9149
# Epoch 3: Train Loss = 0.3089, Train Acc = 0.9118, Val Loss = 0.2140, Val Acc = 0.9157
# Epoch 4: Train Loss = 0.2418, Train Acc = 0.9310, Val Loss = 0.1745, Val Acc = 0.9278
# Epoch 5: Train Loss = 0.2094, Train Acc = 0.9410, Val Loss = 0.1756, Val Acc = 0.9282
# Epoch 6: Train Loss = 0.1660, Train Acc = 0.9529, Val Loss = 0.1837, Val Acc = 0.9400
# Epoch 7: Train Loss = 0.1353, Train Acc = 0.9641, Val Loss = 0.1635, Val Acc = 0.9463
# Epoch 8: Train Loss = 0.1186, Train Acc = 0.9692, Val Loss = 0.1302, Val Acc = 0.9506
# Epoch 9: Train Loss = 0.0935, Train Acc = 0.9753, Val Loss = 0.1132, Val Acc = 0.9553
# Epoch 10: Train Loss = 0.0702, Train Acc = 0.9837, Val Loss = 0.1194, Val Acc = 0.9627
# Epoch 11: Train Loss = 0.0609, Train Acc = 0.9847, Val Loss = 0.1191, Val Acc = 0.9604
# Epoch 12: Train Loss = 0.0516, Train Acc = 0.9862, Val Loss = 0.1255, Val Acc = 0.9643
# Epoch 13: Train Loss = 0.0456, Train Acc = 0.9895, Val Loss = 0.1117, Val Acc = 0.9655
# Epoch 14: Train Loss = 0.0345, Train Acc = 0.9920, Val Loss = 0.1032, Val Acc = 0.9690
# Epoch 15: Train Loss = 0.0404, Train Acc = 0.9898, Val Loss = 0.1105, Val Acc = 0.9675
# Epoch 16: Train Loss = 0.0256, Train Acc = 0.9934, Val Loss = 0.1043, Val Acc = 0.9690
# Epoch 17: Train Loss = 0.0213, Train Acc = 0.9950, Val Loss = 0.1352, Val Acc = 0.9620
# Epoch 18: Train Loss = 0.0215, Train Acc = 0.9950, Val Loss = 0.1069, Val Acc = 0.9718
# Epoch 19: Train Loss = 0.0172, Train Acc = 0.9962, Val Loss = 0.1349, Val Acc = 0.9694
# Epoch 20: Train Loss = 0.0144, Train Acc = 0.9971, Val Loss = 0.1224, Val Acc = 0.9722
#
# Fold 5 Best Val Accuracy: 0.9722

# %% [markdown]
# ## Results Summary

# %%
print("K-FOLD RESULTS SUMMARY")

results_df = pd.DataFrame(fold_results)
print(results_df)

print(f"\nAverage Val Accuracy: {results_df['best_val_acc'].mean():.4f} ± {results_df['best_val_acc'].std():.4f}")

best_fold_idx = results_df['best_val_acc'].idxmax()
print(f"\nBest Fold: {results_df.iloc[best_fold_idx]['fold']} with accuracy {results_df.iloc[best_fold_idx]['best_val_acc']:.4f}")

torch.save(best_models[best_fold_idx], 'best_kfold_model.pth')
# Out:
# K-FOLD RESULTS SUMMARY
#    fold  best_val_acc                                    val_acc_history
# 0     1      0.976872  [0.8957271658173266, 0.9043512348098784, 0.904...
# 1     2      0.972941  [0.8827450980392156, 0.8941176470588236, 0.901...
# 2     3      0.978431  [0.8921568627450981, 0.9023529411764706, 0.910...
# 3     4      0.973333  [0.8937254901960784, 0.8878431372549019, 0.912...
# 4     5      0.972157  [0.9007843137254902, 0.9149019607843137, 0.915...
#
# Average Val Accuracy: 0.9747 ± 0.0027
#
# Best Fold: 3 with accuracy 0.9784

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(10, 6))
colors = ['r', 'g', 'b', 'orange', 'purple']

for i, fold_data in enumerate(fold_results):
    plt.plot(range(1, len(fold_data['val_acc_history']) + 1),
             fold_data['val_acc_history'],
             label=f"Fold {fold_data['fold']}",
             color=colors[i % len(colors)],
             linewidth=2)

plt.title("Validation Accuracy Change per Epoch (All 5 Folds)", fontsize=14, fontweight='bold')
plt.xlabel("Epoch", fontsize=12, fontweight='bold')
plt.ylabel("Validation Accuracy", fontsize=12, fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
